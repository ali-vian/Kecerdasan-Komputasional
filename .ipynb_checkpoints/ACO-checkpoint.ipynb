# %%
import numpy as np
import random
# o = np.array([[1,4,9,11,2],
#              [4,1,3,10,8],
#              [9,3,1,5,10],
#              [11,10,5,1,7],
#              [2,8,10,7,1]])
#         ants = [
#             [[0,4,1,3,2],0.04],
#             [[1,2,3,4,0],0.058824],
#             [[2,1,0,4,3],0.0625]
#                ]

# %%
def generateJarakAntarKota(cities,koor):
    distance = []
    for i in range(len(cities)):
        temp=[]
        for j in range(len(cities)):
            d = np.sqrt((koor[i][0]-koor[j][0])**2+(koor[i][1]-koor[j][1])**2)
            temp.append(d)
        distance.append(temp)
    return  np.array(distance)

# %%
def semutBergerak(jarakKota,initPherom):

    # membuat informasi prior
    prior = 1/jarakKota
    # untuk menandai kota yang telah dilewati
    simpan = [None for i in range(len(jarakKota[0]))]
    # memilih kota pertama acak
    pilih = random.randint(0,len(jarakKota)-1)
    # tandai kota pertama telah dilewati
    simpan[pilih] = pilih
    # untuk menampung hasil kota terpilih
    hasil = [pilih]
    for n in range(len(jarakKota[0])-1):
        # total probabilitas kota yang mungkin dikunjungi
        total = 0
        for i in range(len(jarakKota[0])):
            if i not in simpan :
                total+= initPherom[pilih][i]*prior[pilih][i]
        print()
        print("Total = ",total)   
        
        # probabilitas masing masing rute
        temp = [None for x in range(len(jarakKota[0]))]    
        for j in range(len(jarakKota[0])):
            if j not in simpan : 
                temp[j] = initPherom[pilih][j]*prior[pilih][j]/total
                print(f"P({j}) = ",temp[j])

        # komulatif masing-masing rute
        komulatif = {}
        jml=0
        for k in range(len(temp)):
            if temp[k] != None:
                komulatif[k] = [jml,jml+temp[k]]
                jml+= temp[k]
                print(f"K({k}) = ",komulatif[k])

        # pilih acak
        dob = np.random.rand(1)
        for v,s in komulatif.items():
            if dob>s[0] and dob <= s[1]:
                pilih = v
                simpan[v] = v
                hasil.append(pilih)

    # menghitung delta hasil
    delta = 0
    for i in range(len(hasil)-1):
        delta+=jarakKota[hasil[i+1]][hasil[i]]
    delta = 1/delta
    
    return [hasil,delta]


def updatePheromone(ants,initPherom,rho):
    # evaporasi peromone
    evap = np.array(initPherom)*(1-rho)
    # unpdate Pheromone
    for ant in ants:
        for j in range(len(ant[0])-1):
            evap[ant[0][j]][ant[0][j+1]] += ant[1]
    return evap
            
    
def antColony(iteration,numOfAnt,rho,kota,koor):
    
    jarakAntarKota = generateJarakAntarKota(kota,koor)
    print("Jarak Antar Kota\n",jarakAntarKota)

    initPherom = [[ 0 if i==j else 0.01 for i in range(len(jarakAntarKota))] 
                  for j in range(len(jarakAntarKota[0]))]
    print('Inisialisasi Konsentrasi Pheromone\n',np.array(initPherom))

    for i in range(iteration):
        ants=[]

        for j in range(numOfAnt):
        
            print('\nSemut ',j+1)
            temp = semutBergerak(jarakAntarKota,initPherom)
            print('Kota dilewati : ',temp[0],"Delta: ",temp[1])
            ants.append(temp)

            
        initPherom = updatePheromone(ants,initPherom,rho)
        print()
        print("Update Konsentrasi Pheromone\n",initPherom)
    
    


cities = [0,1,2,3,4]
koor = [(4.24, -1.45),
        (1.81, 3.37),
        (-2.59, 3.69),
        (-5.72, -1.59),
        (2.25, -4.02)]

antColony(2,5,0.5,cities,koor)
# Out:
# Jarak Antar Kota
#  [[0.         5.39789774 8.54801146 9.96098389 3.25038459]
#  [5.39789774 0.         4.41162102 9.01678989 7.40308719]
#  [8.54801146 4.41162102 0.         6.13802085 9.10327963]
#  [9.96098389 9.01678989 6.13802085 0.         8.33221459]
#  [3.25038459 7.40308719 9.10327963 8.33221459 0.        ]]
# Inisialisasi Konsentrasi Pheromone
#  [[0.   0.01 0.01 0.01 0.01]
#  [0.01 0.   0.01 0.01 0.01]
#  [0.01 0.01 0.   0.01 0.01]
#  [0.01 0.01 0.01 0.   0.01]
#  [0.01 0.01 0.01 0.01 0.  ]]
#
# Semut  1
#
# Total =  0.007102911701469263
# P(1) =  0.2608188233923754
# P(2) =  0.16470185409572352
# P(3) =  0.1413387826957579
# P(4) =  0.4331405398161432
# K(1) =  [0, 0.2608188233923754]
# K(2) =  [0.2608188233923754, 0.4255206774880989]
# K(3) =  [0.4255206774880989, 0.5668594601838568]
# K(4) =  [0.5668594601838568, 1.0]
#
# Total =  0.003938392907293788
# P(1) =  0.2815976390609654
# P(2) =  0.4136686411973409
# P(4) =  0.3047337197416935
# K(1) =  [0, 0.2815976390609654]
# K(2) =  [0.2815976390609654, 0.6952662802583063]
# K(4) =  [0.6952662802583063, 0.9999999999999998]
#
# Total =  0.00336524569206839
# P(1) =  0.6735735516817362
# P(4) =  0.3264264483182638
# K(1) =  [0, 0.6735735516817362]
# K(4) =  [0.6735735516817362, 1.0]
#
# Total =  0.0013507878183961091
# P(4) =  1.0
# K(4) =  [0, 1.0]
# Kota dilewati :  [0, 3, 2, 1, 4] Delta:  0.03582468594276805
#
# Semut  2
#
# Total =  0.004942309800774907
# P(0) =  0.20312706688757462
# P(1) =  0.22439753659604564
# P(2) =  0.32964134344755663
# P(4) =  0.24283405306882316
# K(0) =  [0, 0.20312706688757462]
# K(1) =  [0.20312706688757462, 0.42752460348362026]
# K(2) =  [0.42752460348362026, 0.7571659469311769]
# K(4) =  [0.7571659469311769, 1.0]
#
# Total =  0.004535108418778588
# P(0) =  0.25795694803372965
# P(1) =  0.49982057401367586
# P(4) =  0.2422224779525945
# K(0) =  [0, 0.25795694803372965]
# K(1) =  [0.25795694803372965, 0.7577775220474054]
# K(4) =  [0.7577775220474054, 1.0]
#
# Total =  0.0032033608910332573
# P(0) =  0.5783216863959381
# P(4) =  0.42167831360406194
# K(0) =  [0, 0.5783216863959381]
# K(4) =  [0.5783216863959381, 1.0]
#
# Total =  0.003076559008640797
# P(0) =  1.0
# K(0) =  [0, 1.0]
# Kota dilewati :  [3, 2, 1, 4, 0] Delta:  0.04716288447804102
#
# Semut  3
#
# Total =  0.007102911701469263
# K(3) =  [0.10140226029304793, 1.0]
#
# Total =  0.028551157632965427
# P(1) =  0.12546904387371582
# P(2) =  0.8745309561262842
# K(1) =  [0, 0.12546904387371582]
# K(2) =  [0.12546904387371582, 1.0]
#
# Total =  0.019944498876129462
# P(1) =  1.0
# K(1) =  [0, 1.0]
# Kota dilewati :  [4, 0, 3, 2, 1] Delta:  0.042085752467603293
#
# Semut  4
#
# Total =  0.029653196639927958
# P(0) =  0.016927633564628047
# P(1) =  0.12080608014018887
# P(2) =  0.842029663326381
# P(4) =  0.02023662296880203
# K(0) =  [0, 0.016927633564628047]
# K(1) =  [0.016927633564628047, 0.1377337137048169]
# K(2) =  [0.1377337137048169, 0.9797633770311979]
# K(4) =  [0.9797633770311979, 0.9999999999999999]
#
# Total =  0.02764158552907016
# P(0) =  0.1367049416034329
# P(1) =  0.7215396112192692
# P(4) =  0.14175544717729777
# K(0) =  [0, 0.1367049416034329]
# K(1) =  [0.1367049416034329, 0.8582445528227022]
# K(4) =  [0.8582445528227022, 1.0]
#
# Total =  0.0024645660406389727
# P(1) =  0.3758416374504704
# P(4) =  0.6241583625495295
# K(1) =  [0, 0.3758416374504704]
# K(4) =  [0.3758416374504704, 0.9999999999999999]
#
# Total =  0.009492240163365211
# P(1) =  1.0
# K(1) =  [0, 1.0]
# Kota dilewati :  [3, 2, 0, 4, 1] Delta:  0.03946407143025846
#
# Semut  5
#
# Total =  0.02845618035030089
# P(0) =  0.13279158653975415
# P(1) =  0.7008846103239774
# P(3) =  0.0286262882510203
# P(4) =  0.13769751488524817
# K(0) =  [0, 0.13279158653975415]
# K(1) =  [0.13279158653975415, 0.8336761968637316]
# K(3) =  [0.8336761968637316, 0.8623024851147519]
# K(4) =  [0.8623024851147519, 1.0]
#
# Total =  0.019776351177043336
# P(0) =  0.3709772449781168
# P(3) =  0.02803960484064861
# P(4) =  0.6009831501812346
# K(0) =  [0, 0.3709772449781168]
# K(3) =  [0.3709772449781168, 0.3990168498187654]
# K(4) =  [0.3990168498187654, 1.0]
#
# Total =  0.014930258982163972
# P(3) =  0.8969690005941584
# P(4) =  0.10303099940584166
# K(3) =  [0, 0.8969690005941584]
# K(4) =  [0.8969690005941584, 1.0]
#
# Total =  0.0006000805602219693
# P(4) =  1.0
# K(4) =  [0, 1.0]
# Kota dilewati :  [2, 1, 0, 3, 4] Delta:  0.035583747708117036
#
# Update Konsentrasi Pheromone
#  [[0.         0.0025     0.0025     0.18174786 0.09405304]
#  [0.10747376 0.         0.0025     0.0025     0.0813735 ]
#  [0.05561443 0.17375225 0.         0.0025     0.0178349 ]
#  [0.0025     0.01615036 0.24764823 0.         0.03808375]
#  [0.10554691 0.07460001 0.01615036 0.0025     0.        ]]
# C:\Users\Muhammad Alivian\AppData\Local\Temp\ipykernel_17420\2435367499.py:3: RuntimeWarning: divide by zero encountered in divide
#   prior = 1/jarakKota
