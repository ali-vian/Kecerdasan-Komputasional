# %% [markdown]
# ## Soal Akhir
# Buat kode untuk persoalan berikut<br>
# Terdapat beberapa Node yang direpresentasikan seperti dibawah setiap node memiliki titik koordinat x dan y sesuai dengan index lakukan perhitungan antara jarak node dengan tetangganya dengan menggunakan rumus mencari jarak di antara 2 titik sebagai berikut.
# $$ d=\sqrt{(x_2-x_1)^2+(y_2-y_1)^2}\ $$
# ```
# Nodes = [0,1,2,3,4]
# koor = [[0,0],
#         [3,1],
#         [7,0],
#         [7,7],
#         [0,5]]
# ```
# setelah mengetahui jarak masing2 node atau disebut dengan vertex carilah vertex  yang terpendek kemudian tampilkan graphnya matpl !
# <br>untuk outputnya seperti berikut ini
# ![image.png](attachment:image.png)
