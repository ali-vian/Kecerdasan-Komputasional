# %% [markdown]
# ## Fuzzy
# Untuk permasalahan kalasifikasi atau pun bisa mengeluarkan nilai rill (regresi)
# Untuk menentukan kelompok anggotanya ataupun rule butuh expert
#
# ## Genetic algoritm
# Untuk permasalahan optimasi untuk mecari solusi diantara beberapa solusi
#
# ## JST
# preceptron digunakan untuk klasifikasi dan juga bisa digunakan untuk regresi
# Kalau jst untuk menentukan butuh data.

# %% [markdown]
# ## Mengetahui niliai error dari data
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Fungsi identitas fx=x
# kalasifikasi :
# - bainary class : outputnya yes or no
# - multiclass : outputnya seperi binary class tapi lebih dari 2 class yang salah satu saja
# - multilabel : ada banyak class yang bisa kita pilih
#
# 1. sigmoid

# %% [markdown]
# Buat code untuk forwardpropagation

# %%
x = 1960 
y = 901 
print(x % y)
# Out:
# 158
