# %%
import numpy as np

# %%
def generateKoordinatCity(numOfCity):

    count = 0
    temp=[]
    while count < numOfCity :
        coordinate_x= int(input(f"masukkan koordinat kota {count+1} x : "))
        coordinate_y= int(input(f"masukkan koordinat kota {count+1} y : "))
        if [coordinate_x,coordinate_y] not in temp :
            temp.append([coordinate_x,coordinate_y])
            count+=1
    return np.array(temp)

# %%
def generateIndividu(numOfCity):
    ind = np.zeros(numOfCity,dtype=int)-1
    count = 0
    while count < numOfCity:
        temp = np.random.randint(numOfCity)
        if temp not in ind :
            ind[count] = temp
            count += 1
    return ind

# %%
def generatePopulation(individu,numOfCity):
    population = np.zeros([individu,numOfCity],dtype=int)
    for i in range(individu):
        population[i] =  generateIndividu(numOfCity)
    location = generateKoordinatCity(numOfCity)
    return population,location

# %%
def calculateFitness(population,coordinat):
    (numOfIndividu,numOfCity) = population.shape
    fitness = np.zeros(numOfIndividu)
    for i in range(numOfIndividu):
        jarak=0.0
        for j in range(numOfCity-1):
            jarak += np.sqrt(sum((coordinat[population[i,j]]-coordinat[population[i,j+1]])**2))
        fitness[i] = 1/jarak
    return fitness

# %%
def selection(fitness):

    totalFitness = np.sum(fitness)

    probIndividu = fitness/totalFitness
    sizeIndividu= len(fitness)

    komulatif = np.zeros(sizeIndividu+1)
    for i in range(sizeIndividu):
        komulatif[i+1] = komulatif[i]+probIndividu[i]

    count=0
    newProb = np.zeros(sizeIndividu,dtype=int)
    for j in range(sizeIndividu):
        roulette = np.random.rand(1)
        for i in range(sizeIndividu+1):
            if roulette>komulatif[i] and roulette <= komulatif[i+1]:
                newProb[count]=i
        count+=1
    return newProb

# %%
def newPopulation(idx,population):
    newP = np.zeros_like(population)
    for i in range(len(idx)):
        newP[i] = population[idx[i]]
    return newP

# %%
def crossover(population):
    newP = population.copy()
    (numOfIndividu,numOfCity) = population.shape
    for i in range(numOfIndividu):
        ind1,ind2 = np.random.randint(numOfCity),np.random.randint(numOfCity)
        if ind1 <= ind2 :
            temp = ind2
            for j in range(ind1,ind2+1):
                newP[i,j] = population[i,temp]
                temp-=1
        else:
            temp = ind1
            for j in range(ind2,ind1+1):
                newP[i,j] = population[i,temp]
                temp-=1
    return newP

# %%
def mutation(population):
    newP = population.copy()
    (numOfIndividu,numOfCity) = population.shape
    for i in range(numOfIndividu):
        ind1,ind2 = np.random.randint(numOfCity),np.random.randint(numOfCity)
        newP[i,ind1],newP[i,ind2] = newP[i,ind2],newP[i,ind1]
    return newP

# %%
import matplotlib.pyplot as plt
def geneticAlgoritm(numOfPopulation, generation):
    numOfCity = int(input('masukkan jumlah kota : '))
    (population, location) = generatePopulation(numOfPopulation, numOfCity)
    print("Inisialisasi Populasi :\n", population)

    bestPopulation = 0
    bestFitness = 0

    for i in range(generation):
        print(f"Generasi-{i}")
        nilaiFitness = calculateFitness(population, location)
        newInd = selection(nilaiFitness)
        print("Indeks hasil populasi seleksi :", newInd)
        population = newPopulation(newInd, population)
        print("Individu Hasil Seleksi :\n", population)
        population = crossover(population)
        print("Hasil crossover :\n", population)
        population = mutation(population)
        print("Hasil mutasi :\n", population)


        bestIndex = nilaiFitness.argmax()
        if nilaiFitness[bestIndex] > bestFitness:
            bestPopulation = population[bestIndex]
            bestFitness = nilaiFitness[bestIndex]

        disp = []
        for i in range(len(bestPopulation)) :
            disp.append(location[bestPopulation[i]])




    print("\nPopulasi terbaik:")
    print(bestPopulation)
    print("Fitness:", bestFitness)
    print("--------",disp)
    x_points = []
    y_points = []
    for i in disp:
        x_points.append(i[0])
        y_points.append(i[1])
    plt.plot(x_points,y_points)
    return population

# %%
geneticAlgoritm(6,102)
# Out:
# masukkan jumlah kota : 5
# masukkan koordinat kota 1 x : 2
# masukkan koordinat kota 1 y : 7
# masukkan koordinat kota 2 x : 3
# masukkan koordinat kota 2 y : 9
# masukkan koordinat kota 3 x : 4
# masukkan koordinat kota 3 y : 9
# masukkan koordinat kota 4 x : 2
# masukkan koordinat kota 4 y : 4
# masukkan koordinat kota 5 x : 6
# masukkan koordinat kota 5 y : 9
# Inisialisasi Populasi :
#  [[3 0 1 4 2]
#  [3 1 0 2 4]
#  [4 3 1 2 0]
#  [3 2 0 1 4]
#  [3 0 4 2 1]
#  [2 1 3 0 4]]
# Generasi-0
# Indeks hasil populasi seleksi : [5 0 3 2 3 0]
# Individu Hasil Seleksi :
#  [[2 1 3 0 4]
#  [3 0 1 4 2]
#  [3 2 0 1 4]
#  [4 3 1 2 0]
#  [3 2 0 1 4]
#  [3 0 1 4 2]]
# Hasil crossover :
#  [[4 0 3 1 2]
#  [3 0 1 4 2]
#  [1 0 2 3 4]
#  [4 3 2 1 0]
#  [3 2 0 1 4]
#  [3 0 4 1 2]]
# Hasil mutasi :
#  [[0 4 3 1 2]
#  [3 4 1 0 2]
#  [1 0 4 3 2]
#  [4 3 2 1 0]
#  [0 2 3 1 4]
#  [2 0 4 1 3]]
# Generasi-1
# Indeks hasil populasi seleksi : [3 2 0 4 1 3]
# Individu Hasil Seleksi :
#  [[4 3 2 1 0]
#  [1 0 4 3 2]
#  [0 4 3 1 2]
#  [0 2 3 1 4]
#  [3 4 1 0 2]
#  [4 3 2 1 0]]
# Hasil crossover :
#  [[4 3 2 1 0]
#  [1 0 4 2 3]
#  [0 4 3 1 2]
#  [3 2 0 1 4]
#  [1 4 3 0 2]
#  [4 3 0 1 2]]
# Hasil mutasi :
#  [[0 3 2 1 4]
#  [1 0 4 2 3]
#  [0 3 4 1 2]
#  [3 2 0 4 1]
#  [2 4 3 0 1]
#  [1 3 0 4 2]]
# Generasi-2
# Indeks hasil populasi seleksi : [5 3 1 4 5 0]
# Individu Hasil Seleksi :
#  [[1 3 0 4 2]
#  [3 2 0 4 1]
#  [1 0 4 2 3]
#  [2 4 3 0 1]
#  [1 3 0 4 2]
#  [0 3 2 1 4]]
# Hasil crossover :
#  [[1 3 2 4 0]
#  [2 3 0 4 1]
#  [1 3 2 4 0]
#  [2 0 3 4 1]
#  [1 3 2 4 0]
#  [1 2 3 0 4]]
# Hasil mutasi :
#  [[1 3 2 0 4]
#  [4 3 0 2 1]
#  [1 3 2 0 4]
#  [2 0 4 3 1]
#  [1 3 0 4 2]
#  [1 0 3 2 4]]
# Generasi-3
# Indeks hasil populasi seleksi : [3 1 5 1 5 2]
# Individu Hasil Seleksi :
#  [[2 0 4 3 1]
#  [4 3 0 2 1]
#  [1 0 3 2 4]
#  [4 3 0 2 1]
#  [1 0 3 2 4]
#  [1 3 2 0 4]]
# Hasil crossover :
#  [[1 3 4 0 2]
#  [4 3 0 2 1]
#  [0 1 3 2 4]
#  [3 4 0 2 1]
#  [1 0 2 3 4]
#  [1 2 3 0 4]]
# Hasil mutasi :
#  [[3 1 4 0 2]
#  [4 3 1 2 0]
#  [2 1 3 0 4]
#  [1 4 0 2 3]
#  [4 0 2 3 1]
#  [0 2 3 1 4]]
# Generasi-4
# Indeks hasil populasi seleksi : [0 1 3 0 5 2]
# Individu Hasil Seleksi :
#  [[3 1 4 0 2]
#  [4 3 1 2 0]
#  [1 4 0 2 3]
#  [3 1 4 0 2]
#  [0 2 3 1 4]
#  [2 1 3 0 4]]
# Hasil crossover :
#  [[3 0 4 1 2]
#  [4 3 2 1 0]
#  [1 4 0 2 3]
#  [3 4 1 0 2]
#  [0 3 2 1 4]
#  [4 0 3 1 2]]
# Hasil mutasi :
#  [[3 0 1 4 2]
#  [4 1 2 3 0]
#  [1 4 3 2 0]
#  [3 1 4 0 2]
#  [0 1 2 3 4]
#  [4 0 3 1 2]]
# Generasi-5
# Indeks hasil populasi seleksi : [1 1 5 3 5 3]
# Individu Hasil Seleksi :
#  [[4 1 2 3 0]
#  [4 1 2 3 0]
#  [4 0 3 1 2]
#  [3 1 4 0 2]
#  [4 0 3 1 2]
#  [3 1 4 0 2]]
# Hasil crossover :
#  [[1 4 2 3 0]
#  [4 1 2 3 0]
#  [4 0 1 3 2]
#  [3 1 4 0 2]
#  [3 0 4 1 2]
#  [3 0 4 1 2]]
# Hasil mutasi :
#  [[1 4 3 2 0]
#  [4 2 1 3 0]
#  [2 0 1 3 4]
#  [3 0 4 1 2]
#  [3 2 4 1 0]
#  [3 0 2 1 4]]
# Generasi-6
# Indeks hasil populasi seleksi : [5 5 3 3 5 4]
# Individu Hasil Seleksi :
#  [[3 0 2 1 4]
#  [3 0 2 1 4]
#  [3 0 4 1 2]
#  [3 0 4 1 2]
#  [3 0 2 1 4]
#  [3 2 4 1 0]]
# Hasil crossover :
#  [[3 2 0 1 4]
#  [1 2 0 3 4]
#  [4 0 3 1 2]
#  [0 3 4 1 2]
#  [3 0 2 1 4]
#  [4 2 3 1 0]]
# Hasil mutasi :
#  [[3 2 0 4 1]
#  [1 2 0 3 4]
#  [4 1 3 0 2]
#  [0 3 1 4 2]
#  [3 4 2 1 0]
#  [3 2 4 1 0]]
# Generasi-7
# Indeks hasil populasi seleksi : [3 0 1 5 4 5]
# Individu Hasil Seleksi :
#  [[0 3 1 4 2]
#  [3 2 0 4 1]
#  [1 2 0 3 4]
#  [3 2 4 1 0]
#  [3 4 2 1 0]
#  [3 2 4 1 0]]
# Hasil crossover :
#  [[0 1 3 4 2]
#  [3 2 0 4 1]
#  [1 2 3 0 4]
#  [1 4 2 3 0]
#  [0 1 2 4 3]
#  [3 2 4 0 1]]
# Hasil mutasi :
#  [[0 1 2 4 3]
#  [3 2 0 1 4]
#  [1 3 2 0 4]
#  [1 3 2 4 0]
#  [3 1 2 4 0]
#  [2 3 4 0 1]]
# Generasi-8
# Indeks hasil populasi seleksi : [5 2 0 4 3 0]
# Individu Hasil Seleksi :
#  [[2 3 4 0 1]
#  [1 3 2 0 4]
#  [0 1 2 4 3]
#  [3 1 2 4 0]
#  [1 3 2 4 0]
#  [0 1 2 4 3]]
# Hasil crossover :
#  [[2 1 0 4 3]
#  [2 3 1 0 4]
#  [3 4 2 1 0]
#  [3 2 1 4 0]
#  [1 3 4 2 0]
#  [0 1 3 4 2]]
# Hasil mutasi :
#  [[0 1 2 4 3]
#  [0 3 1 2 4]
#  [3 4 2 1 0]
#  [3 2 1 0 4]
#  [3 1 4 2 0]
#  [0 4 3 1 2]]
# Generasi-9
# Indeks hasil populasi seleksi : [1 2 2 5 1 0]
# Individu Hasil Seleksi :
#  [[0 3 1 2 4]
#  [3 4 2 1 0]
#  [3 4 2 1 0]
#  [0 4 3 1 2]
#  [0 3 1 2 4]
#  [0 1 2 4 3]]
# Hasil crossover :
#  [[0 3 1 2 4]
#  [3 4 2 1 0]
#  [3 0 1 2 4]
#  [0 4 3 1 2]
#  [0 4 2 1 3]
#  [0 1 3 4 2]]
# Hasil mutasi :
#  [[0 2 1 3 4]
#  [3 4 2 0 1]
#  [1 0 3 2 4]
#  [0 4 3 1 2]
#  [0 4 3 1 2]
#  [0 1 4 3 2]]
# Generasi-10
# Indeks hasil populasi seleksi : [1 0 4 3 0 5]
# Individu Hasil Seleksi :
#  [[3 4 2 0 1]
#  [0 2 1 3 4]
#  [0 4 3 1 2]
#  [0 4 3 1 2]
#  [0 2 1 3 4]
#  [0 1 4 3 2]]
# Hasil crossover :
#  [[3 4 0 2 1]
#  [3 1 2 0 4]
#  [1 3 4 0 2]
#  [0 4 2 1 3]
#  [4 3 1 2 0]
#  [0 1 3 4 2]]
# Hasil mutasi :
#  [[3 4 2 0 1]
#  [3 2 1 0 4]
#  [0 3 4 1 2]
#  [3 4 2 1 0]
#  [4 2 1 3 0]
#  [1 0 3 4 2]]
# Generasi-11
# Indeks hasil populasi seleksi : [1 4 5 2 5 3]
# Individu Hasil Seleksi :
#  [[3 2 1 0 4]
#  [4 2 1 3 0]
#  [1 0 3 4 2]
#  [0 3 4 1 2]
#  [1 0 3 4 2]
#  [3 4 2 1 0]]
# Hasil crossover :
#  [[3 2 1 4 0]
#  [4 2 1 3 0]
#  [1 3 0 4 2]
#  [0 3 4 2 1]
#  [1 0 3 2 4]
#  [3 4 2 1 0]]
# Hasil mutasi :
#  [[3 2 1 4 0]
#  [3 2 1 4 0]
#  [2 3 0 4 1]
#  [0 3 2 4 1]
#  [1 0 2 3 4]
#  [3 4 1 2 0]]
# Generasi-12
# Indeks hasil populasi seleksi : [0 1 5 2 4 2]
# Individu Hasil Seleksi :
#  [[3 2 1 4 0]
#  [3 2 1 4 0]
#  [3 4 1 2 0]
#  [2 3 0 4 1]
#  [1 0 2 3 4]
#  [2 3 0 4 1]]
# Hasil crossover :
#  [[3 2 4 1 0]
#  [3 2 1 4 0]
#  [3 4 1 2 0]
#  [2 3 0 4 1]
#  [1 2 0 3 4]
#  [3 2 0 4 1]]
# Hasil mutasi :
#  [[4 2 3 1 0]
#  [3 1 2 4 0]
#  [3 1 4 2 0]
#  [2 0 3 4 1]
#  [1 0 2 3 4]
#  [0 2 3 4 1]]
# Generasi-13
# Indeks hasil populasi seleksi : [0 4 3 1 2 0]
# Individu Hasil Seleksi :
#  [[4 2 3 1 0]
#  [1 0 2 3 4]
#  [2 0 3 4 1]
#  [3 1 2 4 0]
#  [3 1 4 2 0]
#  [4 2 3 1 0]]
# Hasil crossover :
#  [[4 2 3 1 0]
#  [2 0 1 3 4]
#  [2 0 3 1 4]
#  [3 1 2 0 4]
#  [4 1 3 2 0]
#  [0 1 3 2 4]]
# Hasil mutasi :
#  [[4 0 3 1 2]
#  [0 2 1 3 4]
#  [2 0 3 4 1]
#  [3 1 4 0 2]
#  [3 1 4 2 0]
#  [4 1 3 2 0]]
# Generasi-14
# Indeks hasil populasi seleksi : [3 3 2 5 2 4]
# Individu Hasil Seleksi :
#  [[3 1 4 0 2]
#  [3 1 4 0 2]
#  [2 0 3 4 1]
#  [4 1 3 2 0]
#  [2 0 3 4 1]
#  [3 1 4 2 0]]
# Hasil crossover :
#  [[1 3 4 0 2]
#  [4 1 3 0 2]
#  [2 1 4 3 0]
#  [4 1 3 2 0]
#  [2 0 3 4 1]
#  [3 2 4 1 0]]
# Hasil mutasi :
#  [[1 3 2 0 4]
#  [4 1 0 3 2]
#  [2 1 4 3 0]
#  [4 2 3 1 0]
#  [2 4 3 0 1]
#  [3 1 4 2 0]]
# Generasi-15
# Indeks hasil populasi seleksi : [4 4 1 4 1 1]
# Individu Hasil Seleksi :
#  [[2 4 3 0 1]
#  [2 4 3 0 1]
#  [4 1 0 3 2]
#  [2 4 3 0 1]
#  [4 1 0 3 2]
#  [4 1 0 3 2]]
# Hasil crossover :
#  [[4 2 3 0 1]
#  [2 0 3 4 1]
#  [4 0 1 3 2]
#  [2 4 0 3 1]
#  [4 0 1 3 2]
#  [4 1 0 3 2]]
# Hasil mutasi :
#  [[0 2 3 4 1]
#  [2 0 3 1 4]
#  [4 2 1 3 0]
#  [2 0 4 3 1]
#  [2 0 1 3 4]
#  [4 3 0 1 2]]
# Generasi-16
# Indeks hasil populasi seleksi : [3 0 1 3 0 2]
# Individu Hasil Seleksi :
#  [[2 0 4 3 1]
#  [0 2 3 4 1]
#  [2 0 3 1 4]
#  [2 0 4 3 1]
#  [0 2 3 4 1]
#  [4 2 1 3 0]]
# Hasil crossover :
#  [[2 0 4 3 1]
#  [0 2 4 3 1]
#  [2 0 3 1 4]
#  [1 3 4 0 2]
#  [0 2 1 4 3]
#  [2 4 1 3 0]]
# Hasil mutasi :
#  [[2 0 1 3 4]
#  [0 4 2 3 1]
#  [0 2 3 1 4]
#  [1 3 0 4 2]
#  [0 2 3 4 1]
#  [2 4 1 0 3]]
# Generasi-17
# Indeks hasil populasi seleksi : [0 5 0 2 5 3]
# Individu Hasil Seleksi :
#  [[2 0 1 3 4]
#  [2 4 1 0 3]
#  [2 0 1 3 4]
#  [0 2 3 1 4]
#  [2 4 1 0 3]
#  [1 3 0 4 2]]
# Hasil crossover :
#  [[2 0 1 3 4]
#  [2 4 1 3 0]
#  [2 0 1 3 4]
#  [0 3 2 1 4]
#  [2 0 1 4 3]
#  [1 2 4 0 3]]
# Hasil mutasi :
#  [[2 0 1 4 3]
#  [2 0 1 3 4]
#  [2 0 1 3 4]
#  [3 0 2 1 4]
#  [0 2 1 4 3]
#  [1 0 4 2 3]]
# Generasi-18
# Indeks hasil populasi seleksi : [5 1 5 2 3 4]
# Individu Hasil Seleksi :
#  [[1 0 4 2 3]
#  [2 0 1 3 4]
#  [1 0 4 2 3]
#  [2 0 1 3 4]
#  [3 0 2 1 4]
#  [0 2 1 4 3]]
# Hasil crossover :
#  [[3 2 4 0 1]
#  [2 0 1 3 4]
#  [2 4 0 1 3]
#  [4 3 1 0 2]
#  [3 0 2 1 4]
#  [0 3 4 1 2]]
# Hasil mutasi :
#  [[3 2 0 4 1]
#  [2 0 4 3 1]
#  [4 2 0 1 3]
#  [2 3 1 0 4]
#  [3 0 4 1 2]
#  [2 3 4 1 0]]
# Generasi-19
# Indeks hasil populasi seleksi : [1 2 4 0 2 2]
# Individu Hasil Seleksi :
#  [[2 0 4 3 1]
#  [4 2 0 1 3]
#  [3 0 4 1 2]
#  [3 2 0 4 1]
#  [4 2 0 1 3]
#  [4 2 0 1 3]]
# Hasil crossover :
#  [[2 0 4 3 1]
#  [3 1 0 2 4]
#  [3 4 0 1 2]
#  [3 4 0 2 1]
#  [4 2 3 1 0]
#  [4 2 1 0 3]]
# Hasil mutasi :
#  [[2 0 1 3 4]
#  [4 1 0 2 3]
#  [3 4 0 1 2]
#  [3 4 1 2 0]
#  [4 2 3 0 1]
#  [4 2 1 0 3]]
# Generasi-20
# Indeks hasil populasi seleksi : [4 5 2 5 5 4]
# Individu Hasil Seleksi :
#  [[4 2 3 0 1]
#  [4 2 1 0 3]
#  [3 4 0 1 2]
#  [4 2 1 0 3]
#  [4 2 1 0 3]
#  [4 2 3 0 1]]
# Hasil crossover :
#  [[4 2 3 1 0]
#  [4 3 0 1 2]
#  [3 2 1 0 4]
#  [4 3 0 1 2]
#  [4 2 1 0 3]
#  [4 1 0 3 2]]
# Hasil mutasi :
#  [[4 1 3 2 0]
#  [4 3 0 1 2]
#  [3 0 1 2 4]
#  [1 3 0 4 2]
#  [0 2 1 4 3]
#  [2 1 0 3 4]]
# Generasi-21
# Indeks hasil populasi seleksi : [5 0 3 3 2 4]
# Individu Hasil Seleksi :
#  [[2 1 0 3 4]
#  [4 1 3 2 0]
#  [1 3 0 4 2]
#  [1 3 0 4 2]
#  [3 0 1 2 4]
#  [0 2 1 4 3]]
# Hasil crossover :
#  [[2 1 0 3 4]
#  [4 1 3 2 0]
#  [1 3 2 4 0]
#  [1 3 0 4 2]
#  [2 1 0 3 4]
#  [0 3 4 1 2]]
# Hasil mutasi :
#  [[2 4 0 3 1]
#  [0 1 3 2 4]
#  [1 3 2 4 0]
#  [1 0 3 4 2]
#  [0 1 2 3 4]
#  [0 3 1 4 2]]
# Generasi-22
# Indeks hasil populasi seleksi : [4 1 4 3 2 5]
# Individu Hasil Seleksi :
#  [[0 1 2 3 4]
#  [0 1 3 2 4]
#  [0 1 2 3 4]
#  [1 0 3 4 2]
#  [1 3 2 4 0]
#  [0 3 1 4 2]]
# Hasil crossover :
#  [[0 1 2 3 4]
#  [0 1 3 2 4]
#  [0 1 3 2 4]
#  [1 0 3 2 4]
#  [1 3 0 4 2]
#  [2 4 1 3 0]]
# Hasil mutasi :
#  [[0 1 3 2 4]
#  [1 0 3 2 4]
#  [0 1 2 3 4]
#  [0 1 3 2 4]
#  [1 0 3 4 2]
#  [3 4 1 2 0]]
# Generasi-23
# Indeks hasil populasi seleksi : [1 1 5 1 0 1]
# Individu Hasil Seleksi :
#  [[1 0 3 2 4]
#  [1 0 3 2 4]
#  [3 4 1 2 0]
#  [1 0 3 2 4]
#  [0 1 3 2 4]
#  [1 0 3 2 4]]
# Hasil crossover :
#  [[1 0 3 4 2]
#  [1 0 3 2 4]
#  [4 3 1 2 0]
#  [1 4 2 3 0]
#  [2 3 1 0 4]
#  [1 0 3 2 4]]
# Hasil mutasi :
#  [[4 0 3 1 2]
#  [2 0 3 1 4]
#  [4 3 1 2 0]
#  [1 4 2 0 3]
#  [4 3 1 0 2]
#  [1 0 2 3 4]]
# Generasi-24
# Indeks hasil populasi seleksi : [3 0 1 1 3 1]
# Individu Hasil Seleksi :
#  [[1 4 2 0 3]
#  [4 0 3 1 2]
#  [2 0 3 1 4]
#  [2 0 3 1 4]
#  [1 4 2 0 3]
#  [2 0 3 1 4]]
# Hasil crossover :
#  [[1 4 2 0 3]
#  [4 0 1 3 2]
#  [2 0 3 1 4]
#  [2 1 3 0 4]
#  [1 4 0 2 3]
#  [2 3 0 1 4]]
# Hasil mutasi :
#  [[1 4 2 0 3]
#  [1 0 4 3 2]
#  [0 2 3 1 4]
#  [2 1 0 3 4]
#  [4 1 0 2 3]
#  [2 3 0 1 4]]
# Generasi-25
# Indeks hasil populasi seleksi : [4 4 0 0 5 2]
# Individu Hasil Seleksi :
#  [[4 1 0 2 3]
#  [4 1 0 2 3]
#  [1 4 2 0 3]
#  [1 4 2 0 3]
#  [2 3 0 1 4]
#  [0 2 3 1 4]]
# Hasil crossover :
#  [[4 0 1 2 3]
#  [2 0 1 4 3]
#  [1 3 0 2 4]
#  [1 2 4 0 3]
#  [2 3 0 1 4]
#  [2 0 3 1 4]]
# Hasil mutasi :
#  [[4 2 1 0 3]
#  [1 0 2 4 3]
#  [0 3 1 2 4]
#  [0 2 4 1 3]
#  [2 3 1 0 4]
#  [3 0 2 1 4]]
# Generasi-26
# Indeks hasil populasi seleksi : [3 0 4 0 3 5]
# Individu Hasil Seleksi :
#  [[0 2 4 1 3]
#  [4 2 1 0 3]
#  [2 3 1 0 4]
#  [4 2 1 0 3]
#  [0 2 4 1 3]
#  [3 0 2 1 4]]
# Hasil crossover :
#  [[0 1 4 2 3]
#  [1 2 4 0 3]
#  [2 3 1 4 0]
#  [4 2 1 0 3]
#  [4 2 0 1 3]
#  [3 0 1 2 4]]
# Hasil mutasi :
#  [[0 1 2 4 3]
#  [1 2 4 0 3]
#  [0 3 1 4 2]
#  [1 2 4 0 3]
#  [3 2 0 1 4]
#  [1 0 3 2 4]]
# Generasi-27
# Indeks hasil populasi seleksi : [0 1 1 3 1 2]
# Individu Hasil Seleksi :
#  [[0 1 2 4 3]
#  [1 2 4 0 3]
#  [1 2 4 0 3]
#  [1 2 4 0 3]
#  [1 2 4 0 3]
#  [0 3 1 4 2]]
# Hasil crossover :
#  [[0 1 4 2 3]
#  [1 2 4 0 3]
#  [1 2 4 0 3]
#  [3 0 4 2 1]
#  [1 0 4 2 3]
#  [0 3 1 4 2]]
# Hasil mutasi :
#  [[0 2 4 1 3]
#  [0 2 4 1 3]
#  [1 2 4 0 3]
#  [3 0 1 2 4]
#  [1 0 2 4 3]
#  [4 3 1 0 2]]
# Generasi-28
# Indeks hasil populasi seleksi : [3 5 3 5 3 0]
# Individu Hasil Seleksi :
#  [[3 0 1 2 4]
#  [4 3 1 0 2]
#  [3 0 1 2 4]
#  [4 3 1 0 2]
#  [3 0 1 2 4]
#  [0 2 4 1 3]]
# Hasil crossover :
#  [[3 0 4 2 1]
#  [0 1 3 4 2]
#  [0 3 1 2 4]
#  [3 4 1 0 2]
#  [3 0 1 4 2]
#  [0 1 4 2 3]]
# Hasil mutasi :
#  [[3 0 4 2 1]
#  [0 3 1 4 2]
#  [0 3 1 2 4]
#  [3 1 4 0 2]
#  [4 0 1 3 2]
#  [0 1 4 2 3]]
# Generasi-29
# Indeks hasil populasi seleksi : [1 0 2 3 2 3]
# Individu Hasil Seleksi :
#  [[0 3 1 4 2]
#  [3 0 4 2 1]
#  [0 3 1 2 4]
#  [3 1 4 0 2]
#  [0 3 1 2 4]
#  [3 1 4 0 2]]
# Hasil crossover :
#  [[0 1 3 4 2]
#  [3 0 4 1 2]
#  [0 3 1 2 4]
#  [4 1 3 0 2]
#  [0 1 3 2 4]
#  [3 1 4 0 2]]
# Hasil mutasi :
#  [[0 1 3 4 2]
#  [3 4 0 1 2]
#  [0 1 3 2 4]
#  [4 1 0 3 2]
#  [4 1 3 2 0]
#  [3 1 4 0 2]]
# Generasi-30
# Indeks hasil populasi seleksi : [2 2 3 2 4 2]
# Individu Hasil Seleksi :
#  [[0 1 3 2 4]
#  [0 1 3 2 4]
#  [4 1 0 3 2]
#  [0 1 3 2 4]
#  [4 1 3 2 0]
#  [0 1 3 2 4]]
# Hasil crossover :
#  [[1 0 3 2 4]
#  [0 2 3 1 4]
#  [3 0 1 4 2]
#  [1 0 3 2 4]
#  [0 2 3 1 4]
#  [3 1 0 2 4]]
# Hasil mutasi :
#  [[1 0 3 2 4]
#  [2 0 3 1 4]
#  [3 0 1 4 2]
#  [0 1 3 2 4]
#  [3 2 0 1 4]
#  [3 1 4 2 0]]
# Generasi-31
# Indeks hasil populasi seleksi : [2 0 2 5 5 2]
# Individu Hasil Seleksi :
#  [[3 0 1 4 2]
#  [1 0 3 2 4]
#  [3 0 1 4 2]
#  [3 1 4 2 0]
#  [3 1 4 2 0]
#  [3 0 1 4 2]]
# Hasil crossover :
#  [[4 1 0 3 2]
#  [1 4 2 3 0]
#  [0 3 1 4 2]
#  [3 4 1 2 0]
#  [3 1 2 4 0]
#  [3 0 1 4 2]]
# Hasil mutasi :
#  [[2 1 0 3 4]
#  [3 4 2 1 0]
#  [2 3 1 4 0]
#  [3 4 1 2 0]
#  [3 1 2 4 0]
#  [1 0 3 4 2]]
# Generasi-32
# Indeks hasil populasi seleksi : [4 0 1 2 4 5]
# Individu Hasil Seleksi :
#  [[3 1 2 4 0]
#  [2 1 0 3 4]
#  [3 4 2 1 0]
#  [2 3 1 4 0]
#  [3 1 2 4 0]
#  [1 0 3 4 2]]
# Hasil crossover :
#  [[3 1 0 4 2]
#  [2 1 0 3 4]
#  [3 4 2 1 0]
#  [2 3 1 4 0]
#  [3 2 1 4 0]
#  [2 4 3 0 1]]
# Hasil mutasi :
#  [[3 1 0 4 2]
#  [1 2 0 3 4]
#  [3 1 2 4 0]
#  [2 3 1 4 0]
#  [3 2 0 4 1]
#  [4 2 3 0 1]]
# Generasi-33
# Indeks hasil populasi seleksi : [1 1 1 1 0 1]
# Individu Hasil Seleksi :
#  [[1 2 0 3 4]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [3 1 0 4 2]
#  [1 2 0 3 4]]
# Hasil crossover :
#  [[1 2 0 4 3]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [1 2 4 3 0]
#  [3 2 4 0 1]
#  [1 2 4 3 0]]
# Hasil mutasi :
#  [[4 2 0 1 3]
#  [2 1 0 3 4]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [0 2 4 3 1]
#  [1 4 2 3 0]]
# Generasi-34
# Indeks hasil populasi seleksi : [2 1 2 2 0 3]
# Individu Hasil Seleksi :
#  [[1 2 0 3 4]
#  [2 1 0 3 4]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [4 2 0 1 3]
#  [1 2 0 3 4]]
# Hasil crossover :
#  [[1 2 0 3 4]
#  [0 1 2 3 4]
#  [1 2 4 3 0]
#  [1 2 0 4 3]
#  [4 3 1 0 2]
#  [1 4 3 0 2]]
# Hasil mutasi :
#  [[1 2 4 3 0]
#  [0 3 2 1 4]
#  [1 2 4 0 3]
#  [1 0 2 4 3]
#  [4 3 0 1 2]
#  [1 2 3 0 4]]
# Generasi-35
# Indeks hasil populasi seleksi : [5 4 1 3 0 5]
# Individu Hasil Seleksi :
#  [[1 2 3 0 4]
#  [4 3 0 1 2]
#  [0 3 2 1 4]
#  [1 0 2 4 3]
#  [1 2 4 3 0]
#  [1 2 3 0 4]]
# Hasil crossover :
#  [[3 2 1 0 4]
#  [4 3 0 2 1]
#  [2 3 0 1 4]
#  [3 4 2 0 1]
#  [1 3 4 2 0]
#  [1 4 0 3 2]]
# Hasil mutasi :
#  [[3 0 1 2 4]
#  [4 3 2 0 1]
#  [2 1 0 3 4]
#  [0 4 2 3 1]
#  [1 3 4 2 0]
#  [1 4 0 3 2]]
# Generasi-36
# Indeks hasil populasi seleksi : [0 0 0 4 3 0]
# Individu Hasil Seleksi :
#  [[3 0 1 2 4]
#  [3 0 1 2 4]
#  [3 0 1 2 4]
#  [1 3 4 2 0]
#  [0 4 2 3 1]
#  [3 0 1 2 4]]
# Hasil crossover :
#  [[3 0 1 2 4]
#  [3 0 1 4 2]
#  [3 0 1 4 2]
#  [1 3 2 4 0]
#  [0 4 2 3 1]
#  [1 0 3 2 4]]
# Hasil mutasi :
#  [[3 0 1 4 2]
#  [1 0 3 4 2]
#  [4 0 1 3 2]
#  [1 3 2 4 0]
#  [4 0 2 3 1]
#  [1 0 3 2 4]]
# Generasi-37
# Indeks hasil populasi seleksi : [1 2 5 5 0 5]
# Individu Hasil Seleksi :
#  [[1 0 3 4 2]
#  [4 0 1 3 2]
#  [1 0 3 2 4]
#  [1 0 3 2 4]
#  [3 0 1 4 2]
#  [1 0 3 2 4]]
# Hasil crossover :
#  [[3 0 1 4 2]
#  [1 0 4 3 2]
#  [4 2 3 0 1]
#  [2 3 0 1 4]
#  [3 2 4 1 0]
#  [4 2 3 0 1]]
# Hasil mutasi :
#  [[3 0 1 4 2]
#  [1 2 4 3 0]
#  [4 2 3 1 0]
#  [2 1 0 3 4]
#  [3 2 0 1 4]
#  [4 1 3 0 2]]
# Generasi-38
# Indeks hasil populasi seleksi : [5 5 3 0 0 4]
# Individu Hasil Seleksi :
#  [[4 1 3 0 2]
#  [4 1 3 0 2]
#  [2 1 0 3 4]
#  [3 0 1 4 2]
#  [3 0 1 4 2]
#  [3 2 0 1 4]]
# Hasil crossover :
#  [[4 2 0 3 1]
#  [1 4 3 0 2]
#  [2 1 0 3 4]
#  [4 1 0 3 2]
#  [0 3 1 4 2]
#  [3 2 4 1 0]]
# Hasil mutasi :
#  [[4 2 0 3 1]
#  [1 4 3 0 2]
#  [2 1 0 3 4]
#  [4 1 0 2 3]
#  [0 4 1 3 2]
#  [4 2 3 1 0]]
# Generasi-39
# Indeks hasil populasi seleksi : [3 1 5 2 2 3]
# Individu Hasil Seleksi :
#  [[4 1 0 2 3]
#  [1 4 3 0 2]
#  [4 2 3 1 0]
#  [2 1 0 3 4]
#  [2 1 0 3 4]
#  [4 1 0 2 3]]
# Hasil crossover :
#  [[4 1 3 2 0]
#  [3 4 1 0 2]
#  [4 2 3 0 1]
#  [2 0 1 3 4]
#  [1 2 0 3 4]
#  [4 1 2 0 3]]
# Hasil mutasi :
#  [[4 2 3 1 0]
#  [3 1 4 0 2]
#  [4 3 2 0 1]
#  [2 0 1 3 4]
#  [1 2 4 3 0]
#  [4 1 2 3 0]]
# Generasi-40
# Indeks hasil populasi seleksi : [2 3 1 4 4 0]
# Individu Hasil Seleksi :
#  [[4 3 2 0 1]
#  [2 0 1 3 4]
#  [3 1 4 0 2]
#  [1 2 4 3 0]
#  [1 2 4 3 0]
#  [4 2 3 1 0]]
# Hasil crossover :
#  [[4 1 0 2 3]
#  [2 0 1 4 3]
#  [3 1 4 0 2]
#  [1 0 3 4 2]
#  [1 2 4 0 3]
#  [4 2 3 1 0]]
# Hasil mutasi :
#  [[4 1 2 0 3]
#  [2 0 3 4 1]
#  [3 1 4 0 2]
#  [1 0 3 4 2]
#  [1 2 4 0 3]
#  [4 2 0 1 3]]
# Generasi-41
# Indeks hasil populasi seleksi : [5 2 0 2 2 4]
# Individu Hasil Seleksi :
#  [[4 2 0 1 3]
#  [3 1 4 0 2]
#  [4 1 2 0 3]
#  [3 1 4 0 2]
#  [3 1 4 0 2]
#  [1 2 4 0 3]]
# Hasil crossover :
#  [[2 4 0 1 3]
#  [1 3 4 0 2]
#  [4 1 2 3 0]
#  [2 0 4 1 3]
#  [0 4 1 3 2]
#  [1 2 4 0 3]]
# Hasil mutasi :
#  [[2 3 0 1 4]
#  [1 3 4 0 2]
#  [0 1 2 3 4]
#  [2 3 4 1 0]
#  [0 4 1 3 2]
#  [4 2 1 0 3]]
# Generasi-42
# Indeks hasil populasi seleksi : [1 0 0 0 4 4]
# Individu Hasil Seleksi :
#  [[1 3 4 0 2]
#  [2 3 0 1 4]
#  [2 3 0 1 4]
#  [2 3 0 1 4]
#  [0 4 1 3 2]
#  [0 4 1 3 2]]
# Hasil crossover :
#  [[1 3 4 0 2]
#  [2 1 0 3 4]
#  [2 1 0 3 4]
#  [2 4 1 0 3]
#  [0 2 3 1 4]
#  [0 4 1 3 2]]
# Hasil mutasi :
#  [[1 3 4 0 2]
#  [1 2 0 3 4]
#  [2 1 0 3 4]
#  [4 2 1 0 3]
#  [0 2 3 1 4]
#  [0 4 2 3 1]]
# Generasi-43
# Indeks hasil populasi seleksi : [0 4 5 1 1 2]
# Individu Hasil Seleksi :
#  [[1 3 4 0 2]
#  [0 2 3 1 4]
#  [0 4 2 3 1]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [2 1 0 3 4]]
# Hasil crossover :
#  [[2 0 4 3 1]
#  [0 3 2 1 4]
#  [3 2 4 0 1]
#  [1 2 3 0 4]
#  [1 2 4 3 0]
#  [2 1 0 3 4]]
# Hasil mutasi :
#  [[2 0 3 4 1]
#  [0 3 2 4 1]
#  [3 2 0 4 1]
#  [1 3 2 0 4]
#  [1 2 3 4 0]
#  [2 1 0 3 4]]
# Generasi-44
# Indeks hasil populasi seleksi : [5 2 4 5 5 5]
# Individu Hasil Seleksi :
#  [[2 1 0 3 4]
#  [3 2 0 4 1]
#  [1 2 3 4 0]
#  [2 1 0 3 4]
#  [2 1 0 3 4]
#  [2 1 0 3 4]]
# Hasil crossover :
#  [[2 1 0 3 4]
#  [3 1 4 0 2]
#  [1 2 4 3 0]
#  [2 1 0 3 4]
#  [4 3 0 1 2]
#  [2 1 3 0 4]]
# Hasil mutasi :
#  [[2 3 0 1 4]
#  [3 1 4 2 0]
#  [1 2 4 3 0]
#  [2 1 3 0 4]
#  [4 3 0 1 2]
#  [2 1 0 3 4]]
# Generasi-45
# Indeks hasil populasi seleksi : [0 4 5 0 1 0]
# Individu Hasil Seleksi :
#  [[2 3 0 1 4]
#  [4 3 0 1 2]
#  [2 1 0 3 4]
#  [2 3 0 1 4]
#  [3 1 4 2 0]
#  [2 3 0 1 4]]
# Hasil crossover :
#  [[2 3 4 1 0]
#  [4 0 3 1 2]
#  [2 0 1 3 4]
#  [4 1 0 3 2]
#  [3 4 1 2 0]
#  [2 1 0 3 4]]
# Hasil mutasi :
#  [[2 3 4 1 0]
#  [4 0 3 1 2]
#  [2 0 3 1 4]
#  [4 1 0 3 2]
#  [2 4 1 3 0]
#  [2 1 0 3 4]]
# Generasi-46
# Indeks hasil populasi seleksi : [5 0 4 2 3 4]
# Individu Hasil Seleksi :
#  [[2 1 0 3 4]
#  [2 3 4 1 0]
#  [2 4 1 3 0]
#  [2 0 3 1 4]
#  [4 1 0 3 2]
#  [2 4 1 3 0]]
# Hasil crossover :
#  [[2 1 4 3 0]
#  [2 3 4 1 0]
#  [2 4 1 3 0]
#  [2 0 1 3 4]
#  [4 3 0 1 2]
#  [4 2 1 3 0]]
# Hasil mutasi :
#  [[2 1 4 0 3]
#  [2 3 0 1 4]
#  [2 4 3 1 0]
#  [2 0 1 4 3]
#  [4 3 0 1 2]
#  [0 2 1 3 4]]
# Generasi-47
# Indeks hasil populasi seleksi : [0 5 2 3 1 2]
# Individu Hasil Seleksi :
#  [[2 1 4 0 3]
#  [0 2 1 3 4]
#  [2 4 3 1 0]
#  [2 0 1 4 3]
#  [2 3 0 1 4]
#  [2 4 3 1 0]]
# Hasil crossover :
#  [[2 4 1 0 3]
#  [0 2 4 3 1]
#  [2 4 0 1 3]
#  [0 2 1 4 3]
#  [0 3 2 1 4]
#  [2 4 0 1 3]]
# Hasil mutasi :
#  [[2 4 0 1 3]
#  [0 2 4 3 1]
#  [2 0 4 1 3]
#  [0 3 1 4 2]
#  [2 3 0 1 4]
#  [2 4 3 1 0]]
# Generasi-48
# Indeks hasil populasi seleksi : [0 0 1 5 0 4]
# Individu Hasil Seleksi :
#  [[2 4 0 1 3]
#  [2 4 0 1 3]
#  [0 2 4 3 1]
#  [2 4 3 1 0]
#  [2 4 0 1 3]
#  [2 3 0 1 4]]
# Hasil crossover :
#  [[2 0 4 1 3]
#  [2 4 3 1 0]
#  [0 2 1 3 4]
#  [2 4 1 3 0]
#  [2 4 3 1 0]
#  [2 3 4 1 0]]
# Hasil mutasi :
#  [[2 0 4 1 3]
#  [4 2 3 1 0]
#  [2 0 1 3 4]
#  [2 4 1 3 0]
#  [1 4 3 2 0]
#  [3 2 4 1 0]]
# Generasi-49
# Indeks hasil populasi seleksi : [3 3 1 3 5 2]
# Individu Hasil Seleksi :
#  [[2 4 1 3 0]
#  [2 4 1 3 0]
#  [4 2 3 1 0]
#  [2 4 1 3 0]
#  [3 2 4 1 0]
#  [2 0 1 3 4]]
# Hasil crossover :
#  [[2 4 1 3 0]
#  [2 0 3 1 4]
#  [1 3 2 4 0]
#  [2 4 1 3 0]
#  [2 3 4 1 0]
#  [2 3 1 0 4]]
# Hasil mutasi :
#  [[2 4 1 3 0]
#  [2 3 0 1 4]
#  [1 3 4 2 0]
#  [2 3 1 4 0]
#  [2 3 1 4 0]
#  [2 1 3 0 4]]
# Generasi-50
# Indeks hasil populasi seleksi : [1 4 1 4 5 1]
# Individu Hasil Seleksi :
#  [[2 3 0 1 4]
#  [2 3 1 4 0]
#  [2 3 0 1 4]
#  [2 3 1 4 0]
#  [2 1 3 0 4]
#  [2 3 0 1 4]]
# Hasil crossover :
#  [[3 2 0 1 4]
#  [2 3 1 4 0]
#  [2 0 3 1 4]
#  [0 4 1 3 2]
#  [2 1 3 0 4]
#  [1 0 3 2 4]]
# Hasil mutasi :
#  [[2 3 0 1 4]
#  [4 3 1 2 0]
#  [2 0 3 1 4]
#  [0 1 4 3 2]
#  [1 2 3 0 4]
#  [1 3 0 2 4]]
# Generasi-51
# Indeks hasil populasi seleksi : [0 2 1 0 1 0]
# Individu Hasil Seleksi :
#  [[2 3 0 1 4]
#  [2 0 3 1 4]
#  [4 3 1 2 0]
#  [2 3 0 1 4]
#  [4 3 1 2 0]
#  [2 3 0 1 4]]
# Hasil crossover :
#  [[2 1 0 3 4]
#  [2 0 3 4 1]
#  [4 0 2 1 3]
#  [2 3 1 0 4]
#  [1 3 4 2 0]
#  [2 3 0 1 4]]
# Hasil mutasi :
#  [[4 1 0 3 2]
#  [2 0 3 1 4]
#  [4 0 2 1 3]
#  [2 3 0 1 4]
#  [1 3 4 0 2]
#  [2 3 0 1 4]]
# Generasi-52
# Indeks hasil populasi seleksi : [3 0 3 2 5 3]
# Individu Hasil Seleksi :
#  [[2 3 0 1 4]
#  [4 1 0 3 2]
#  [2 3 0 1 4]
#  [4 0 2 1 3]
#  [2 3 0 1 4]
#  [2 3 0 1 4]]
# Hasil crossover :
#  [[2 3 4 1 0]
#  [0 1 4 3 2]
#  [2 0 3 1 4]
#  [4 3 1 2 0]
#  [2 4 1 0 3]
#  [0 3 2 1 4]]
# Hasil mutasi :
#  [[2 3 0 1 4]
#  [0 1 4 3 2]
#  [2 4 3 1 0]
#  [1 3 4 2 0]
#  [0 4 1 2 3]
#  [0 3 4 1 2]]
# Generasi-53
# Indeks hasil populasi seleksi : [3 0 0 0 4 3]
# Individu Hasil Seleksi :
#  [[1 3 4 2 0]
#  [2 3 0 1 4]
#  [2 3 0 1 4]
#  [2 3 0 1 4]
#  [0 4 1 2 3]
#  [1 3 4 2 0]]
# Hasil crossover :
#  [[2 4 3 1 0]
#  [4 1 0 3 2]
#  [0 3 2 1 4]
#  [2 3 0 4 1]
#  [0 3 2 1 4]
#  [1 3 4 2 0]]
# Hasil mutasi :
#  [[2 1 3 4 0]
#  [2 1 0 3 4]
#  [0 3 2 1 4]
#  [2 3 4 0 1]
#  [0 2 3 1 4]
#  [1 3 0 2 4]]
# Generasi-54
# Indeks hasil populasi seleksi : [5 5 1 1 5 0]
# Individu Hasil Seleksi :
#  [[1 3 0 2 4]
#  [1 3 0 2 4]
#  [2 1 0 3 4]
#  [2 1 0 3 4]
#  [1 3 0 2 4]
#  [2 1 3 4 0]]
# Hasil crossover :
#  [[1 3 2 0 4]
#  [3 1 0 2 4]
#  [2 1 3 0 4]
#  [2 1 0 3 4]
#  [1 3 0 2 4]
#  [3 1 2 4 0]]
# Hasil mutasi :
#  [[1 3 2 0 4]
#  [2 1 0 3 4]
#  [2 3 1 0 4]
#  [2 1 0 4 3]
#  [1 3 4 2 0]
#  [4 1 2 3 0]]
# Generasi-55
# Indeks hasil populasi seleksi : [4 1 4 0 2 5]
# Individu Hasil Seleksi :
#  [[1 3 4 2 0]
#  [2 1 0 3 4]
#  [1 3 4 2 0]
#  [1 3 2 0 4]
#  [2 3 1 0 4]
#  [4 1 2 3 0]]
# Hasil crossover :
#  [[0 2 4 3 1]
#  [3 0 1 2 4]
#  [4 3 1 2 0]
#  [1 3 0 2 4]
#  [2 3 4 0 1]
#  [4 1 0 3 2]]
# Hasil mutasi :
#  [[0 2 4 3 1]
#  [3 0 2 1 4]
#  [4 3 2 1 0]
#  [1 4 0 2 3]
#  [2 3 1 0 4]
#  [3 1 0 4 2]]
# Generasi-56
# Indeks hasil populasi seleksi : [2 2 2 4 3 0]
# Individu Hasil Seleksi :
#  [[4 3 2 1 0]
#  [4 3 2 1 0]
#  [4 3 2 1 0]
#  [2 3 1 0 4]
#  [1 4 0 2 3]
#  [0 2 4 3 1]]
# Hasil crossover :
#  [[4 3 0 1 2]
#  [1 2 3 4 0]
#  [4 3 0 1 2]
#  [1 3 2 0 4]
#  [1 4 0 2 3]
#  [0 4 2 3 1]]
# Hasil mutasi :
#  [[4 1 0 3 2]
#  [1 4 3 2 0]
#  [4 3 0 2 1]
#  [0 3 2 1 4]
#  [1 2 0 4 3]
#  [0 4 2 1 3]]
# Generasi-57
# Indeks hasil populasi seleksi : [3 0 1 1 0 4]
# Individu Hasil Seleksi :
#  [[0 3 2 1 4]
#  [4 1 0 3 2]
#  [1 4 3 2 0]
#  [1 4 3 2 0]
#  [4 1 0 3 2]
#  [1 2 0 4 3]]
# Hasil crossover :
#  [[0 2 3 1 4]
#  [4 1 0 3 2]
#  [0 2 3 4 1]
#  [1 4 0 2 3]
#  [4 0 1 3 2]
#  [1 2 0 4 3]]
# Hasil mutasi :
#  [[0 2 3 1 4]
#  [0 1 4 3 2]
#  [0 2 3 4 1]
#  [1 4 3 2 0]
#  [4 0 1 3 2]
#  [3 2 0 4 1]]
# Generasi-58
# Indeks hasil populasi seleksi : [2 5 1 3 5 1]
# Individu Hasil Seleksi :
#  [[0 2 3 4 1]
#  [3 2 0 4 1]
#  [0 1 4 3 2]
#  [1 4 3 2 0]
#  [3 2 0 4 1]
#  [0 1 4 3 2]]
# Hasil crossover :
#  [[0 4 3 2 1]
#  [3 2 0 4 1]
#  [0 1 3 4 2]
#  [1 4 0 2 3]
#  [2 3 0 4 1]
#  [1 0 4 3 2]]
# Hasil mutasi :
#  [[2 4 3 0 1]
#  [2 3 0 4 1]
#  [0 3 1 4 2]
#  [1 4 0 2 3]
#  [2 3 0 4 1]
#  [1 0 2 3 4]]
# Generasi-59
# Indeks hasil populasi seleksi : [4 5 5 3 2 2]
# Individu Hasil Seleksi :
#  [[2 3 0 4 1]
#  [1 0 2 3 4]
#  [1 0 2 3 4]
#  [1 4 0 2 3]
#  [0 3 1 4 2]
#  [0 3 1 4 2]]
# Hasil crossover :
#  [[2 3 0 4 1]
#  [0 1 2 3 4]
#  [1 3 2 0 4]
#  [4 1 0 2 3]
#  [1 3 0 4 2]
#  [0 3 1 4 2]]
# Hasil mutasi :
#  [[2 0 3 4 1]
#  [0 3 2 1 4]
#  [1 3 2 0 4]
#  [1 4 0 2 3]
#  [1 4 0 3 2]
#  [0 4 1 3 2]]
# Generasi-60
# Indeks hasil populasi seleksi : [3 2 2 0 0 2]
# Individu Hasil Seleksi :
#  [[1 4 0 2 3]
#  [1 3 2 0 4]
#  [1 3 2 0 4]
#  [2 0 3 4 1]
#  [2 0 3 4 1]
#  [1 3 2 0 4]]
# Hasil crossover :
#  [[1 4 0 2 3]
#  [2 3 1 0 4]
#  [1 3 2 0 4]
#  [0 2 3 4 1]
#  [2 0 3 4 1]
#  [1 3 4 0 2]]
# Hasil mutasi :
#  [[1 4 0 3 2]
#  [2 3 1 0 4]
#  [0 3 2 1 4]
#  [1 2 3 4 0]
#  [2 4 3 0 1]
#  [2 3 4 0 1]]
# Generasi-61
# Indeks hasil populasi seleksi : [2 0 5 1 1 3]
# Individu Hasil Seleksi :
#  [[0 3 2 1 4]
#  [1 4 0 3 2]
#  [2 3 4 0 1]
#  [2 3 1 0 4]
#  [2 3 1 0 4]
#  [1 2 3 4 0]]
# Hasil crossover :
#  [[0 4 1 2 3]
#  [2 3 0 4 1]
#  [2 3 0 4 1]
#  [2 3 1 0 4]
#  [2 3 1 0 4]
#  [1 2 3 0 4]]
# Hasil mutasi :
#  [[0 4 1 3 2]
#  [4 3 0 2 1]
#  [2 3 4 0 1]
#  [4 3 1 0 2]
#  [2 0 1 3 4]
#  [3 2 1 0 4]]
# Generasi-62
# Indeks hasil populasi seleksi : [1 5 3 2 3 0]
# Individu Hasil Seleksi :
#  [[4 3 0 2 1]
#  [3 2 1 0 4]
#  [4 3 1 0 2]
#  [2 3 4 0 1]
#  [4 3 1 0 2]
#  [0 4 1 3 2]]
# Hasil crossover :
#  [[4 3 1 2 0]
#  [3 4 0 1 2]
#  [1 3 4 0 2]
#  [2 3 4 0 1]
#  [2 0 1 3 4]
#  [0 4 2 3 1]]
# Hasil mutasi :
#  [[0 3 1 2 4]
#  [3 0 4 1 2]
#  [1 3 0 4 2]
#  [2 0 4 3 1]
#  [2 0 1 4 3]
#  [0 2 4 3 1]]
# Generasi-63
# Indeks hasil populasi seleksi : [2 2 0 4 1 1]
# Individu Hasil Seleksi :
#  [[1 3 0 4 2]
#  [1 3 0 4 2]
#  [0 3 1 2 4]
#  [2 0 1 4 3]
#  [3 0 4 1 2]
#  [3 0 4 1 2]]
# Hasil crossover :
#  [[1 3 4 0 2]
#  [1 3 4 0 2]
#  [0 3 1 2 4]
#  [4 1 0 2 3]
#  [3 4 0 1 2]
#  [3 2 1 4 0]]
# Hasil mutasi :
#  [[1 3 4 0 2]
#  [1 3 0 4 2]
#  [0 3 1 2 4]
#  [2 1 0 4 3]
#  [0 4 3 1 2]
#  [3 0 1 4 2]]
# Generasi-64
# Indeks hasil populasi seleksi : [3 4 2 5 0 3]
# Individu Hasil Seleksi :
#  [[2 1 0 4 3]
#  [0 4 3 1 2]
#  [0 3 1 2 4]
#  [3 0 1 4 2]
#  [1 3 4 0 2]
#  [2 1 0 4 3]]
# Hasil crossover :
#  [[2 1 4 0 3]
#  [0 4 3 1 2]
#  [0 2 1 3 4]
#  [3 0 1 2 4]
#  [1 3 0 4 2]
#  [2 1 0 4 3]]
# Hasil mutasi :
#  [[0 1 4 2 3]
#  [0 4 2 1 3]
#  [0 2 4 3 1]
#  [3 0 4 2 1]
#  [1 3 4 0 2]
#  [2 0 1 4 3]]
# Generasi-65
# Indeks hasil populasi seleksi : [1 1 5 1 1 5]
# Individu Hasil Seleksi :
#  [[0 4 2 1 3]
#  [0 4 2 1 3]
#  [2 0 1 4 3]
#  [0 4 2 1 3]
#  [0 4 2 1 3]
#  [2 0 1 4 3]]
# Hasil crossover :
#  [[2 4 0 1 3]
#  [0 3 1 2 4]
#  [2 0 3 4 1]
#  [0 2 4 1 3]
#  [1 2 4 0 3]
#  [2 4 1 0 3]]
# Hasil mutasi :
#  [[2 4 0 1 3]
#  [1 3 0 2 4]
#  [2 0 3 1 4]
#  [0 2 4 3 1]
#  [1 0 4 2 3]
#  [4 2 1 0 3]]
# Generasi-66
# Indeks hasil populasi seleksi : [4 2 4 4 2 1]
# Individu Hasil Seleksi :
#  [[1 0 4 2 3]
#  [2 0 3 1 4]
#  [1 0 4 2 3]
#  [1 0 4 2 3]
#  [2 0 3 1 4]
#  [1 3 0 2 4]]
# Hasil crossover :
#  [[1 3 2 4 0]
#  [2 4 1 3 0]
#  [3 2 4 0 1]
#  [1 0 4 2 3]
#  [3 0 2 1 4]
#  [1 3 0 2 4]]
# Hasil mutasi :
#  [[1 3 2 4 0]
#  [4 2 1 3 0]
#  [3 2 4 0 1]
#  [1 0 4 3 2]
#  [3 0 2 4 1]
#  [2 3 0 1 4]]
# Generasi-67
# Indeks hasil populasi seleksi : [0 4 4 3 4 4]
# Individu Hasil Seleksi :
#  [[1 3 2 4 0]
#  [3 0 2 4 1]
#  [3 0 2 4 1]
#  [1 0 4 3 2]
#  [3 0 2 4 1]
#  [3 0 2 4 1]]
# Hasil crossover :
#  [[4 2 3 1 0]
#  [2 0 3 4 1]
#  [3 0 2 4 1]
#  [1 0 4 3 2]
#  [3 2 0 4 1]
#  [3 2 0 4 1]]
# Hasil mutasi :
#  [[4 2 3 1 0]
#  [3 0 2 4 1]
#  [2 0 3 4 1]
#  [4 0 1 3 2]
#  [3 0 2 4 1]
#  [3 2 0 4 1]]
# Generasi-68
# Indeks hasil populasi seleksi : [4 5 5 0 2 4]
# Individu Hasil Seleksi :
#  [[3 0 2 4 1]
#  [3 2 0 4 1]
#  [3 2 0 4 1]
#  [4 2 3 1 0]
#  [2 0 3 4 1]
#  [3 0 2 4 1]]
# Hasil crossover :
#  [[4 2 0 3 1]
#  [3 2 1 4 0]
#  [3 2 4 0 1]
#  [1 3 2 4 0]
#  [2 0 1 4 3]
#  [3 0 1 4 2]]
# Hasil mutasi :
#  [[4 2 3 0 1]
#  [0 2 1 4 3]
#  [3 4 2 0 1]
#  [1 0 2 4 3]
#  [2 0 1 4 3]
#  [4 0 1 3 2]]
# Generasi-69
# Indeks hasil populasi seleksi : [2 5 0 1 1 5]
# Individu Hasil Seleksi :
#  [[3 4 2 0 1]
#  [4 0 1 3 2]
#  [4 2 3 0 1]
#  [0 2 1 4 3]
#  [0 2 1 4 3]
#  [4 0 1 3 2]]
# Hasil crossover :
#  [[3 4 2 0 1]
#  [1 0 4 3 2]
#  [3 2 4 0 1]
#  [2 0 1 4 3]
#  [0 2 3 4 1]
#  [4 0 1 3 2]]
# Hasil mutasi :
#  [[3 2 4 0 1]
#  [1 0 4 3 2]
#  [0 2 4 3 1]
#  [2 1 0 4 3]
#  [3 2 0 4 1]
#  [4 3 1 0 2]]
# Generasi-70
# Indeks hasil populasi seleksi : [1 3 3 2 2 2]
# Individu Hasil Seleksi :
#  [[1 0 4 3 2]
#  [2 1 0 4 3]
#  [2 1 0 4 3]
#  [0 2 4 3 1]
#  [0 2 4 3 1]
#  [0 2 4 3 1]]
# Hasil crossover :
#  [[1 0 4 2 3]
#  [2 1 3 4 0]
#  [2 1 0 4 3]
#  [1 3 4 2 0]
#  [0 2 4 3 1]
#  [4 2 0 3 1]]
# Hasil mutasi :
#  [[1 0 3 2 4]
#  [2 1 3 4 0]
#  [2 1 0 3 4]
#  [1 3 2 4 0]
#  [0 2 4 1 3]
#  [4 3 0 2 1]]
# Generasi-71
# Indeks hasil populasi seleksi : [2 3 1 4 2 2]
# Individu Hasil Seleksi :
#  [[2 1 0 3 4]
#  [1 3 2 4 0]
#  [2 1 3 4 0]
#  [0 2 4 1 3]
#  [2 1 0 3 4]
#  [2 1 0 3 4]]
# Hasil crossover :
#  [[2 1 3 0 4]
#  [2 3 1 4 0]
#  [2 1 4 3 0]
#  [0 1 4 2 3]
#  [4 3 0 1 2]
#  [2 3 0 1 4]]
# Hasil mutasi :
#  [[1 2 3 0 4]
#  [2 3 1 4 0]
#  [2 1 3 4 0]
#  [0 4 1 2 3]
#  [4 3 0 1 2]
#  [2 3 4 1 0]]
# Generasi-72
# Indeks hasil populasi seleksi : [4 3 5 5 3 5]
# Individu Hasil Seleksi :
#  [[4 3 0 1 2]
#  [0 4 1 2 3]
#  [2 3 4 1 0]
#  [2 3 4 1 0]
#  [0 4 1 2 3]
#  [2 3 4 1 0]]
# Hasil crossover :
#  [[4 0 3 1 2]
#  [1 4 0 2 3]
#  [2 0 1 4 3]
#  [2 3 4 1 0]
#  [2 1 4 0 3]
#  [2 1 4 3 0]]
# Hasil mutasi :
#  [[1 0 3 4 2]
#  [1 4 0 2 3]
#  [4 0 1 2 3]
#  [2 1 4 3 0]
#  [2 1 4 0 3]
#  [1 2 4 3 0]]
# Generasi-73
# Indeks hasil populasi seleksi : [5 1 3 4 2 1]
# Individu Hasil Seleksi :
#  [[1 2 4 3 0]
#  [1 4 0 2 3]
#  [2 1 4 3 0]
#  [2 1 4 0 3]
#  [4 0 1 2 3]
#  [1 4 0 2 3]]
# Hasil crossover :
#  [[3 4 2 1 0]
#  [1 3 2 0 4]
#  [2 0 3 4 1]
#  [0 4 1 2 3]
#  [4 0 3 2 1]
#  [1 4 0 2 3]]
# Hasil mutasi :
#  [[3 4 2 1 0]
#  [1 3 2 4 0]
#  [2 1 3 4 0]
#  [4 0 1 2 3]
#  [4 0 3 2 1]
#  [1 0 4 2 3]]
# Generasi-74
# Indeks hasil populasi seleksi : [5 0 0 1 4 5]
# Individu Hasil Seleksi :
#  [[1 0 4 2 3]
#  [3 4 2 1 0]
#  [3 4 2 1 0]
#  [1 3 2 4 0]
#  [4 0 3 2 1]
#  [1 0 4 2 3]]
# Hasil crossover :
#  [[1 0 3 2 4]
#  [3 4 1 2 0]
#  [3 4 0 1 2]
#  [2 3 1 4 0]
#  [3 0 4 2 1]
#  [3 2 4 0 1]]
# Hasil mutasi :
#  [[1 0 2 3 4]
#  [3 1 4 2 0]
#  [3 4 0 1 2]
#  [2 3 1 4 0]
#  [3 0 2 4 1]
#  [3 1 4 0 2]]
# Generasi-75
# Indeks hasil populasi seleksi : [4 0 3 0 5 2]
# Individu Hasil Seleksi :
#  [[3 0 2 4 1]
#  [1 0 2 3 4]
#  [2 3 1 4 0]
#  [1 0 2 3 4]
#  [3 1 4 0 2]
#  [3 4 0 1 2]]
# Hasil crossover :
#  [[4 2 0 3 1]
#  [1 0 4 3 2]
#  [2 3 1 4 0]
#  [1 2 0 3 4]
#  [3 1 4 0 2]
#  [3 4 0 1 2]]
# Hasil mutasi :
#  [[3 2 0 4 1]
#  [1 4 0 3 2]
#  [0 3 1 4 2]
#  [1 2 0 3 4]
#  [3 0 4 1 2]
#  [3 1 0 4 2]]
# Generasi-76
# Indeks hasil populasi seleksi : [1 2 3 5 0 1]
# Individu Hasil Seleksi :
#  [[1 4 0 3 2]
#  [0 3 1 4 2]
#  [1 2 0 3 4]
#  [3 1 0 4 2]
#  [3 2 0 4 1]
#  [1 4 0 3 2]]
# Hasil crossover :
#  [[2 3 0 4 1]
#  [0 3 1 4 2]
#  [1 2 0 3 4]
#  [3 1 4 0 2]
#  [2 3 0 4 1]
#  [0 4 1 3 2]]
# Hasil mutasi :
#  [[3 2 0 4 1]
#  [0 4 1 3 2]
#  [1 2 0 3 4]
#  [3 1 2 0 4]
#  [2 0 3 4 1]
#  [0 4 3 1 2]]
# Generasi-77
# Indeks hasil populasi seleksi : [3 5 1 1 3 3]
# Individu Hasil Seleksi :
#  [[3 1 2 0 4]
#  [0 4 3 1 2]
#  [0 4 1 3 2]
#  [0 4 1 3 2]
#  [3 1 2 0 4]
#  [3 1 2 0 4]]
# Hasil crossover :
#  [[3 1 2 0 4]
#  [0 4 3 2 1]
#  [0 4 1 3 2]
#  [4 0 1 3 2]
#  [3 1 4 0 2]
#  [3 0 2 1 4]]
# Hasil mutasi :
#  [[1 3 2 0 4]
#  [0 2 3 4 1]
#  [0 3 1 4 2]
#  [4 0 1 3 2]
#  [3 2 4 0 1]
#  [3 2 0 1 4]]
# Generasi-78
# Indeks hasil populasi seleksi : [0 4 0 5 2 4]
# Individu Hasil Seleksi :
#  [[1 3 2 0 4]
#  [3 2 4 0 1]
#  [1 3 2 0 4]
#  [3 2 0 1 4]
#  [0 3 1 4 2]
#  [3 2 4 0 1]]
# Hasil crossover :
#  [[3 1 2 0 4]
#  [3 2 4 0 1]
#  [3 1 2 0 4]
#  [3 1 0 2 4]
#  [2 4 1 3 0]
#  [3 2 4 0 1]]
# Hasil mutasi :
#  [[3 2 1 0 4]
#  [1 2 4 0 3]
#  [3 1 2 0 4]
#  [4 1 0 2 3]
#  [2 4 1 3 0]
#  [3 2 4 1 0]]
# Generasi-79
# Indeks hasil populasi seleksi : [1 5 5 1 3 1]
# Individu Hasil Seleksi :
#  [[1 2 4 0 3]
#  [3 2 4 1 0]
#  [3 2 4 1 0]
#  [1 2 4 0 3]
#  [4 1 0 2 3]
#  [1 2 4 0 3]]
# Hasil crossover :
#  [[1 2 4 0 3]
#  [3 4 2 1 0]
#  [3 2 4 1 0]
#  [1 2 4 3 0]
#  [4 2 0 1 3]
#  [0 4 2 1 3]]
# Hasil mutasi :
#  [[3 2 4 0 1]
#  [2 4 3 1 0]
#  [3 2 4 1 0]
#  [4 2 1 3 0]
#  [2 4 0 1 3]
#  [0 1 2 4 3]]
# Generasi-80
# Indeks hasil populasi seleksi : [2 4 4 3 2 2]
# Individu Hasil Seleksi :
#  [[3 2 4 1 0]
#  [2 4 0 1 3]
#  [2 4 0 1 3]
#  [4 2 1 3 0]
#  [3 2 4 1 0]
#  [3 2 4 1 0]]
# Hasil crossover :
#  [[3 2 4 0 1]
#  [1 0 4 2 3]
#  [4 2 0 1 3]
#  [4 2 0 3 1]
#  [1 4 2 3 0]
#  [2 3 4 1 0]]
# Hasil mutasi :
#  [[1 2 4 0 3]
#  [1 4 0 2 3]
#  [2 4 0 1 3]
#  [4 3 0 2 1]
#  [1 4 2 3 0]
#  [2 1 4 3 0]]
# Generasi-81
# Indeks hasil populasi seleksi : [5 4 1 1 4 0]
# Individu Hasil Seleksi :
#  [[2 1 4 3 0]
#  [1 4 2 3 0]
#  [1 4 0 2 3]
#  [1 4 0 2 3]
#  [1 4 2 3 0]
#  [1 2 4 0 3]]
# Hasil crossover :
#  [[2 1 3 4 0]
#  [1 4 2 3 0]
#  [1 2 0 4 3]
#  [1 2 0 4 3]
#  [1 3 2 4 0]
#  [1 2 3 0 4]]
# Hasil mutasi :
#  [[2 1 3 4 0]
#  [4 1 2 3 0]
#  [1 4 0 2 3]
#  [1 2 0 3 4]
#  [1 4 2 3 0]
#  [1 4 3 0 2]]
# Generasi-82
# Indeks hasil populasi seleksi : [3 3 3 0 1 0]
# Individu Hasil Seleksi :
#  [[1 2 0 3 4]
#  [1 2 0 3 4]
#  [1 2 0 3 4]
#  [2 1 3 4 0]
#  [4 1 2 3 0]
#  [2 1 3 4 0]]
# Hasil crossover :
#  [[1 2 0 3 4]
#  [1 2 0 4 3]
#  [4 3 0 2 1]
#  [4 3 1 2 0]
#  [4 2 1 3 0]
#  [2 1 3 4 0]]
# Hasil mutasi :
#  [[4 2 0 3 1]
#  [1 3 0 4 2]
#  [4 3 2 0 1]
#  [4 1 3 2 0]
#  [2 4 1 3 0]
#  [2 3 1 4 0]]
# Generasi-83
# Indeks hasil populasi seleksi : [0 4 3 3 2 4]
# Individu Hasil Seleksi :
#  [[4 2 0 3 1]
#  [2 4 1 3 0]
#  [4 1 3 2 0]
#  [4 1 3 2 0]
#  [4 3 2 0 1]
#  [2 4 1 3 0]]
# Hasil crossover :
#  [[4 1 3 0 2]
#  [2 4 1 3 0]
#  [4 1 3 2 0]
#  [0 2 3 1 4]
#  [4 2 3 0 1]
#  [0 3 1 4 2]]
# Hasil mutasi :
#  [[4 0 3 1 2]
#  [3 4 1 2 0]
#  [4 0 3 2 1]
#  [0 2 4 1 3]
#  [0 2 3 4 1]
#  [1 3 0 4 2]]
# Generasi-84
# Indeks hasil populasi seleksi : [1 4 3 5 3 5]
# Individu Hasil Seleksi :
#  [[3 4 1 2 0]
#  [0 2 3 4 1]
#  [0 2 4 1 3]
#  [1 3 0 4 2]
#  [0 2 4 1 3]
#  [1 3 0 4 2]]
# Hasil crossover :
#  [[3 4 1 0 2]
#  [0 2 3 1 4]
#  [0 2 4 1 3]
#  [1 3 0 4 2]
#  [4 2 0 1 3]
#  [1 0 3 4 2]]
# Hasil mutasi :
#  [[4 3 1 0 2]
#  [0 2 3 1 4]
#  [0 2 4 1 3]
#  [1 2 0 4 3]
#  [3 2 0 1 4]
#  [2 0 3 4 1]]
# Generasi-85
# Indeks hasil populasi seleksi : [0 5 1 2 1 4]
# Individu Hasil Seleksi :
#  [[4 3 1 0 2]
#  [2 0 3 4 1]
#  [0 2 3 1 4]
#  [0 2 4 1 3]
#  [0 2 3 1 4]
#  [3 2 0 1 4]]
# Hasil crossover :
#  [[4 3 1 0 2]
#  [2 0 3 4 1]
#  [0 1 3 2 4]
#  [0 2 4 1 3]
#  [0 2 1 3 4]
#  [3 2 0 1 4]]
# Hasil mutasi :
#  [[4 3 1 0 2]
#  [2 0 3 1 4]
#  [0 1 3 2 4]
#  [0 4 2 1 3]
#  [2 0 1 3 4]
#  [3 2 0 1 4]]
# Generasi-86
# Indeks hasil populasi seleksi : [0 2 3 0 2 3]
# Individu Hasil Seleksi :
#  [[4 3 1 0 2]
#  [0 1 3 2 4]
#  [0 4 2 1 3]
#  [4 3 1 0 2]
#  [0 1 3 2 4]
#  [0 4 2 1 3]]
# Hasil crossover :
#  [[4 0 1 3 2]
#  [0 1 4 2 3]
#  [0 4 2 3 1]
#  [3 4 1 0 2]
#  [0 1 3 2 4]
#  [0 4 2 1 3]]
# Hasil mutasi :
#  [[4 2 1 3 0]
#  [0 3 4 2 1]
#  [0 1 2 3 4]
#  [0 4 1 3 2]
#  [0 1 3 4 2]
#  [0 4 3 1 2]]
# Generasi-87
# Indeks hasil populasi seleksi : [3 3 1 5 1 0]
# Individu Hasil Seleksi :
#  [[0 4 1 3 2]
#  [0 4 1 3 2]
#  [0 3 4 2 1]
#  [0 4 3 1 2]
#  [0 3 4 2 1]
#  [4 2 1 3 0]]
# Hasil crossover :
#  [[0 4 1 3 2]
#  [0 1 4 3 2]
#  [3 0 4 2 1]
#  [3 4 0 1 2]
#  [0 3 2 4 1]
#  [2 4 1 3 0]]
# Hasil mutasi :
#  [[0 4 2 3 1]
#  [2 1 4 3 0]
#  [3 2 4 0 1]
#  [3 0 4 1 2]
#  [1 3 2 4 0]
#  [2 1 4 3 0]]
# Generasi-88
# Indeks hasil populasi seleksi : [1 5 5 3 2 3]
# Individu Hasil Seleksi :
#  [[2 1 4 3 0]
#  [2 1 4 3 0]
#  [2 1 4 3 0]
#  [3 0 4 1 2]
#  [3 2 4 0 1]
#  [3 0 4 1 2]]
# Hasil crossover :
#  [[4 1 2 3 0]
#  [4 1 2 3 0]
#  [2 0 3 4 1]
#  [4 0 3 1 2]
#  [3 4 2 0 1]
#  [4 0 3 1 2]]
# Hasil mutasi :
#  [[4 2 1 3 0]
#  [4 1 2 3 0]
#  [2 0 3 4 1]
#  [4 3 0 1 2]
#  [4 3 2 0 1]
#  [1 0 3 4 2]]
# Generasi-89
# Indeks hasil populasi seleksi : [0 2 5 4 2 4]
# Individu Hasil Seleksi :
#  [[4 2 1 3 0]
#  [2 0 3 4 1]
#  [1 0 3 4 2]
#  [4 3 2 0 1]
#  [2 0 3 4 1]
#  [4 3 2 0 1]]
# Hasil crossover :
#  [[4 0 3 1 2]
#  [4 3 0 2 1]
#  [1 0 3 4 2]
#  [2 3 4 0 1]
#  [0 2 3 4 1]
#  [4 1 0 2 3]]
# Hasil mutasi :
#  [[3 0 4 1 2]
#  [2 3 0 4 1]
#  [1 0 3 2 4]
#  [2 3 1 0 4]
#  [0 2 3 1 4]
#  [4 1 0 2 3]]
# Generasi-90
# Indeks hasil populasi seleksi : [3 3 3 5 5 5]
# Individu Hasil Seleksi :
#  [[2 3 1 0 4]
#  [2 3 1 0 4]
#  [2 3 1 0 4]
#  [4 1 0 2 3]
#  [4 1 0 2 3]
#  [4 1 0 2 3]]
# Hasil crossover :
#  [[0 1 3 2 4]
#  [2 4 0 1 3]
#  [2 3 0 1 4]
#  [4 0 1 2 3]
#  [1 4 0 2 3]
#  [4 1 0 2 3]]
# Hasil mutasi :
#  [[2 1 3 0 4]
#  [2 4 1 0 3]
#  [2 0 3 1 4]
#  [4 0 1 2 3]
#  [1 4 2 0 3]
#  [4 1 0 2 3]]
# Generasi-91
# Indeks hasil populasi seleksi : [1 3 0 1 0 3]
# Individu Hasil Seleksi :
#  [[2 4 1 0 3]
#  [4 0 1 2 3]
#  [2 1 3 0 4]
#  [2 4 1 0 3]
#  [2 1 3 0 4]
#  [4 0 1 2 3]]
# Hasil crossover :
#  [[2 4 1 0 3]
#  [4 0 1 3 2]
#  [2 3 1 0 4]
#  [2 4 0 1 3]
#  [2 1 0 3 4]
#  [4 0 1 3 2]]
# Hasil mutasi :
#  [[2 4 1 0 3]
#  [1 0 4 3 2]
#  [4 3 1 0 2]
#  [4 2 0 1 3]
#  [1 2 0 3 4]
#  [4 0 1 2 3]]
# Generasi-92
# Indeks hasil populasi seleksi : [3 1 3 3 5 0]
# Individu Hasil Seleksi :
#  [[4 2 0 1 3]
#  [1 0 4 3 2]
#  [4 2 0 1 3]
#  [4 2 0 1 3]
#  [4 0 1 2 3]
#  [2 4 1 0 3]]
# Hasil crossover :
#  [[4 2 3 1 0]
#  [1 0 4 3 2]
#  [4 2 1 0 3]
#  [4 3 1 0 2]
#  [4 0 2 1 3]
#  [0 1 4 2 3]]
# Hasil mutasi :
#  [[4 0 3 1 2]
#  [4 0 1 3 2]
#  [2 4 1 0 3]
#  [1 3 4 0 2]
#  [4 3 2 1 0]
#  [0 1 2 4 3]]
# Generasi-93
# Indeks hasil populasi seleksi : [2 3 4 5 4 4]
# Individu Hasil Seleksi :
#  [[2 4 1 0 3]
#  [1 3 4 0 2]
#  [4 3 2 1 0]
#  [0 1 2 4 3]
#  [4 3 2 1 0]
#  [4 3 2 1 0]]
# Hasil crossover :
#  [[0 1 4 2 3]
#  [1 3 4 0 2]
#  [4 0 1 2 3]
#  [4 2 1 0 3]
#  [4 3 2 1 0]
#  [0 1 2 3 4]]
# Hasil mutasi :
#  [[0 1 4 2 3]
#  [1 3 2 0 4]
#  [4 0 1 3 2]
#  [4 2 1 3 0]
#  [4 0 2 1 3]
#  [0 1 2 3 4]]
# Generasi-94
# Indeks hasil populasi seleksi : [5 3 3 4 5 3]
# Individu Hasil Seleksi :
#  [[0 1 2 3 4]
#  [4 2 1 3 0]
#  [4 2 1 3 0]
#  [4 0 2 1 3]
#  [0 1 2 3 4]
#  [4 2 1 3 0]]
# Hasil crossover :
#  [[0 1 2 4 3]
#  [4 2 1 3 0]
#  [4 2 1 3 0]
#  [1 2 0 4 3]
#  [2 1 0 3 4]
#  [4 2 1 0 3]]
# Hasil mutasi :
#  [[0 2 1 4 3]
#  [1 2 4 3 0]
#  [4 0 1 3 2]
#  [1 2 3 4 0]
#  [2 3 0 1 4]
#  [4 1 2 0 3]]
# Generasi-95
# Indeks hasil populasi seleksi : [0 5 4 0 5 5]
# Individu Hasil Seleksi :
#  [[0 2 1 4 3]
#  [4 1 2 0 3]
#  [2 3 0 1 4]
#  [0 2 1 4 3]
#  [4 1 2 0 3]
#  [4 1 2 0 3]]
# Hasil crossover :
#  [[1 2 0 4 3]
#  [4 3 0 2 1]
#  [2 1 0 3 4]
#  [0 2 1 3 4]
#  [4 2 1 0 3]
#  [4 1 2 0 3]]
# Hasil mutasi :
#  [[4 2 0 1 3]
#  [0 3 4 2 1]
#  [0 1 2 3 4]
#  [0 3 1 2 4]
#  [4 2 3 0 1]
#  [4 1 3 0 2]]
# Generasi-96
# Indeks hasil populasi seleksi : [4 5 3 5 1 4]
# Individu Hasil Seleksi :
#  [[4 2 3 0 1]
#  [4 1 3 0 2]
#  [0 3 1 2 4]
#  [4 1 3 0 2]
#  [0 3 4 2 1]
#  [4 2 3 0 1]]
# Hasil crossover :
#  [[4 3 2 0 1]
#  [1 4 3 0 2]
#  [0 3 1 4 2]
#  [2 0 3 1 4]
#  [4 3 0 2 1]
#  [4 3 2 0 1]]
# Hasil mutasi :
#  [[4 3 1 0 2]
#  [1 4 2 0 3]
#  [0 3 1 4 2]
#  [2 0 3 1 4]
#  [3 4 0 2 1]
#  [4 3 2 1 0]]
# Generasi-97
# Indeks hasil populasi seleksi : [1 4 4 5 5 1]
# Individu Hasil Seleksi :
#  [[1 4 2 0 3]
#  [3 4 0 2 1]
#  [3 4 0 2 1]
#  [4 3 2 1 0]
#  [4 3 2 1 0]
#  [1 4 2 0 3]]
# Hasil crossover :
#  [[1 4 2 0 3]
#  [3 4 2 0 1]
#  [0 4 3 2 1]
#  [4 3 2 1 0]
#  [4 3 1 2 0]
#  [3 0 2 4 1]]
# Hasil mutasi :
#  [[3 4 2 0 1]
#  [4 3 2 0 1]
#  [4 0 3 2 1]
#  [0 3 2 1 4]
#  [4 3 1 2 0]
#  [1 0 2 4 3]]
# Generasi-98
# Indeks hasil populasi seleksi : [4 4 0 3 4 1]
# Individu Hasil Seleksi :
#  [[4 3 1 2 0]
#  [4 3 1 2 0]
#  [3 4 2 0 1]
#  [0 3 2 1 4]
#  [4 3 1 2 0]
#  [4 3 2 0 1]]
# Hasil crossover :
#  [[1 3 4 2 0]
#  [4 3 1 2 0]
#  [3 4 1 0 2]
#  [0 2 3 1 4]
#  [4 3 2 1 0]
#  [4 3 2 0 1]]
# Hasil mutasi :
#  [[1 2 4 3 0]
#  [4 1 3 2 0]
#  [1 4 3 0 2]
#  [0 2 3 1 4]
#  [1 3 2 4 0]
#  [4 3 2 1 0]]
# Generasi-99
# Indeks hasil populasi seleksi : [1 1 2 4 2 3]
# Individu Hasil Seleksi :
#  [[4 1 3 2 0]
#  [4 1 3 2 0]
#  [1 4 3 0 2]
#  [1 3 2 4 0]
#  [1 4 3 0 2]
#  [0 2 3 1 4]]
# Hasil crossover :
#  [[0 2 3 1 4]
#  [4 1 3 2 0]
#  [1 2 0 3 4]
#  [1 3 2 4 0]
#  [1 4 3 0 2]
#  [4 1 3 2 0]]
# Hasil mutasi :
#  [[2 0 3 1 4]
#  [4 1 3 0 2]
#  [1 0 2 3 4]
#  [1 3 4 2 0]
#  [3 4 1 0 2]
#  [4 1 2 3 0]]
# Generasi-100
# Indeks hasil populasi seleksi : [2 0 5 3 4 3]
# Individu Hasil Seleksi :
#  [[1 0 2 3 4]
#  [2 0 3 1 4]
#  [4 1 2 3 0]
#  [1 3 4 2 0]
#  [3 4 1 0 2]
#  [1 3 4 2 0]]
# Hasil crossover :
#  [[1 0 3 2 4]
#  [3 0 2 1 4]
#  [2 1 4 3 0]
#  [3 1 4 2 0]
#  [3 4 1 0 2]
#  [1 4 3 2 0]]
# Hasil mutasi :
#  [[1 0 3 2 4]
#  [3 0 4 1 2]
#  [2 1 4 0 3]
#  [4 1 3 2 0]
#  [3 0 1 4 2]
#  [1 2 3 4 0]]
# Generasi-101
# Indeks hasil populasi seleksi : [2 4 2 5 3 4]
# Individu Hasil Seleksi :
#  [[2 1 4 0 3]
#  [3 0 1 4 2]
#  [2 1 4 0 3]
#  [1 2 3 4 0]
#  [4 1 3 2 0]
#  [3 0 1 4 2]]
# Hasil crossover :
#  [[2 1 4 0 3]
#  [3 0 1 4 2]
#  [2 4 1 0 3]
#  [1 2 3 4 0]
#  [4 1 3 2 0]
#  [2 4 1 0 3]]
# Hasil mutasi :
#  [[3 1 4 0 2]
#  [3 1 0 4 2]
#  [2 0 1 4 3]
#  [2 1 3 4 0]
#  [4 1 0 2 3]
#  [2 0 1 4 3]]
#
# Populasi terbaik:
# [2 1 0 3 4]
# Fitness: 0.12141716201613581
# -------- [array([4, 9]), array([3, 9]), array([2, 7]), array([2, 4]), array([6, 9])]
# array([[3, 1, 4, 0, 2],
#        [3, 1, 0, 4, 2],
#        [2, 0, 1, 4, 3],
#        [2, 1, 3, 4, 0],
#        [4, 1, 0, 2, 3],
#        [2, 0, 1, 4, 3]])
